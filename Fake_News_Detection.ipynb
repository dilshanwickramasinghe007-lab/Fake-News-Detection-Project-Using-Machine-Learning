# %% [markdown]
# <a href="https://colab.research.google.com/github/dilshanwickramasinghe007-lab/Fake-News-Detection-Project-Using-Machine-Learning/blob/main/Fake_News_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
true = pd.read_csv('/content/sample_data/True.csv')

# %%
fake = pd.read_csv('/content/sample_data/Fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label'] = 1

# %%
fake['label'] = 0

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news = pd.concat([fake, true], axis = 0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news = news.drop(['title', 'subject','date'], axis = 1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
news = news.sample(frac = 1)        #Reshuffling

# %%
news.head()
# Out:
#                                                     text  label
# 18596  The White House confirmed to FOX Business that...      0
# 8153   Donald Trump supporters have taken it upon the...      0
# 22493  Tune in to the Alternate Current Radio Network...      0
# 6490   PARIS (Reuters) - Nissan is halting joint deve...      1
# 11626        https://www.youtube.com/watch?v=uCS4RB9G13M      0

# %%
news = pd.concat([fake, true], axis = 0)
news = news.drop(['title', 'subject','date'], axis = 1)
news = news.sample(frac = 1)
news.reset_index(inplace = True)
news.head()
# Out:
#    index                                               text  label
# 0   2499  PHILADELPHIA (Reuters) - The mayor of Allentow...      1
# 1    961  Former Attorney General Eric Holder, who serve...      0
# 2  15959  What will he think of next? Is Kim Jong-un is ...      0
# 3    517  SACRAMENTO, Calif. (Reuters) - California lawm...      1
# 4   2253  WASHINGTON (Reuters) - President Donald Trump’...      1

# %%
news.drop(['index'], axis = 1, inplace = True)

# %%
news.head()
# Out:
#                                                 text  label
# 0  PHILADELPHIA (Reuters) - The mayor of Allentow...      1
# 1  Former Attorney General Eric Holder, who serve...      0
# 2  What will he think of next? Is Kim Jong-un is ...      0
# 3  SACRAMENTO, Calif. (Reuters) - California lawm...      1
# 4  WASHINGTON (Reuters) - President Donald Trump’...      1

# %%
import re

# %%
def wordopt(text):
#convert into lowercase
  text = text.lower()
#remove URLs
  text = re.sub(r'https/://\S+|www\.\S+', '', text )
#remove HTML tags
  text = re.sub(r'<,*?>','', text)
#remove punctuation
  text = re.sub(r'[^\w\s]','', text)
#remove digits
  text = re.sub(r'\d','', text)
#remove newline characters
  text = re.sub(r'\n', '', text)
  return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        philadelphia reuters  the mayor of allentown t...
# 1        former attorney general eric holder who served...
# 2        what will he think of next is kim jongun is pr...
# 3        sacramento calif reuters  california lawmaker ...
# 4        washington reuters  president donald trumps vo...
#                                ...
# 44893     the times asserts that such censorship would ...
# 44894    washington reuters  us democratic lawmakers ca...
# 44895    buenos aires reuters  us president barack obam...
# 44896    but is threatening trump on social media consi...
# 44897    washington reuters  former central intelligenc...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
x
# Out:
# 0        philadelphia reuters  the mayor of allentown t...
# 1        former attorney general eric holder who served...
# 2        what will he think of next is kim jongun is pr...
# 3        sacramento calif reuters  california lawmaker ...
# 4        washington reuters  president donald trumps vo...
#                                ...
# 44893     the times asserts that such censorship would ...
# 44894    washington reuters  us democratic lawmakers ca...
# 44895    buenos aires reuters  us president barack obam...
# 44896    but is threatening trump on social media consi...
# 44897    washington reuters  former central intelligenc...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 44893    0
# 44894    1
# 44895    1
# 44896    0
# 44897    1
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
Vectorization = TfidfVectorizer()

# %%
xv_train = Vectorization.fit_transform(x_train)

# %%
xv_test = Vectorization.transform(x_test)

# %%
xv_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 6450625 stored elements and shape (31428, 177202)>

# %%
xv_test
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2733302 stored elements and shape (13470, 177202)>

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9893095768374165

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7049
#            1       0.99      0.99      0.99      6421
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()

# %%
DTC.fit(xv_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test, y_test)
# Out:
# 0.9955456570155902

# %%
print(classification_report(y_test, pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7049
#            1       1.00      1.00      1.00      6421
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(xv_train, y_train)
# Out:
# RandomForestClassifier()

# %%
pred_rfc = rfc.predict(xv_test)

# %%
rfc.score(xv_test, y_test)
# Out:
# 0.9876763177431329

# %%
print(classification_report(y_test, pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7049
#            1       0.99      0.99      0.99      6421
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_gbc = gbc.predict(xv_test)

# %%
gbc.score(xv_test, y_test)
# Out:
# 0.9959910913140312

# %%
print(classification_report(y_test, pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      7049
#            1       0.99      1.00      1.00      6421
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
def output_lable(n):
    if n == 0:
        return "Fake News"
    elif n == 1:
        return "Not A Fake News"

# %%
def manual_testing(news):
    testing_news = {"text":[news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test["text"]
    new_xv_test = Vectorization.transform(new_x_test)
    pred_lr = LR.predict(new_xv_test)
    pred_gbc = gbc.predict(new_xv_test)
    pred_rfc = rfc.predict(new_xv_test)
    return "\n\nLR Prediction: {} \nGBC Prediction: {} \nRFC Prediction: {}".format(
        output_lable(pred_lr[0]),
        output_lable(pred_gbc[0]),
        output_lable(pred_rfc[0])
    )

# %%
news_article = str(input())
# Out:
# Trump Said Some INSANELY Racist Stuff Inside The Oval Office, And Witnesses Back It Up"

# %%
manual_testing(news_article)
# Out:
# '\n\nLR Prediction: Fake News \nGBC Prediction: Fake News \nRFC Prediction: Fake News'
